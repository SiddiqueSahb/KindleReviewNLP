# %% [markdown]
# # Best Practises
# 1. Preprocessing And Cleaning
# 2. Train Test Spitl
# 3.
# BOW,TFIDF,Wordvec
# 4.
# Train ML algorih
# hms

# %% [markdown]
# ## Load the dataset

# %%
import pandas as pd
file_path = 'C:\Users\Admin\Desktop\NLP\kindle_review.csv'
data = pd.read_csv(file_path,)
# Out:
#   Cell In[32], line 2
#     file_path = 'C:\Users\Admin\Desktop\NLP\kindle_review.csv'
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pwd
# Out:
# 'C:\\Users\\Admin'
